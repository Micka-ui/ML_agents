# %%
import tensorflow as tf 
from tensorflow import keras 
import matplotlib.pyplot as plt
import numpy as np

# %%
physical_devices = tf.config.list_physical_devices(
    device_type=None
)
# Out:
# 2022-02-11 08:48:46.433625: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-11 08:48:46.438755: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-02-11 08:48:46.438769: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
physical_devices
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
tf.config.experimental.set_memory_growth(physical_devices[1], True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 tf.config.experimental.set_memory_growth(physical_devices[1], True)
#
# IndexError: list index out of range

# %%
env = gym.make('LunarLanderContinuous-v2')
import gym
from gym import wrappers

env.reset()

# %%
print( 'state space :' ,env.observation_space)
print( 'action space :' ,env.action_space)

# %%
class Noise(object):
    def __init__(self, mu, sigma = 0.15,theta =0.2,dt = 1e-2,x0=None):
        self.theta = theta 
        self.mu = mu
        self.sigma = sigma 
        self.dt = dt
        self.x0 = x0
        self.reset()
        
    def __call__(self):
        x = self.x_prev + self.theta*(self.mu-self.x_prev)*self.dt+\
        self.sigma*np.sqrt(self.dt)*np.random.normal(size = self.mu.shape)
        self.prev_x = x 
        return x
    
    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

# %%
class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_ctr = 0 
        self.state_memory = np.zeros((self.mem_size,input_shape))
        self.new_state_memory = np.zeros((self.mem_size,input_shape))
        self.action_memory = np.zeros((self.mem_size,n_actions))
        self.reward_memory = np.zeros(self.mem_size)
        self.terminal_memory = np.zeros(self.mem_size,dtype = np.float32)
        
    def store_transition(self,state,action,reward,next_state,done):
        index = self.mem_ctr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = next_state
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = done 
        self.mem_ctr+=1
        
    def sample_buffer(self,batch_size):
        max_mem = min(self.mem_ctr,self.mem_size)
        batch = np.random.choice(max_mem, batch_size)
        states = self.state_memory[batch]
        new_states = self.new_state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        terminal = self.terminal_memory[batch]
        
        return states, actions, rewards, new_states, terminal 


class Actor(tf.keras.Model):
    def __init__(self,n_actions,action_bounds,input_dims):
        super(Actor,self).__init__()
        self.list_layers = []
        self.n_layers = 2
        self.action_bounds = action_bounds
        self.list_layers.append(keras.layers.Input(shape=(input_dims,)))
        for i in range(self.n_layers):
            self.list_layers.append(keras.layers.BatchNormalization())
            self.list_layers.append(tf.keras.layers.Dense(512,activation = 'relu'))
        self.list_layers.append(keras.layers.BatchNormalization())
        self.list_layers.append(keras.layers.Dense(n_actions,activation = 'tanh'))
        self.actor = keras.Sequential(self.list_layers)
    def __call__(self,inputs):
        Z = self.actor(inputs)
        v_min,v_max = self.action_bounds
        Z = tf.clip_by_value(Z,v_min,v_max)
        return Z 
    
class Critic(tf.keras.Model):
    def __init__(self,input_dims,n_actions,num_layers = 2):
        super(Critic,self).__init__()
        self.list_layers = []
        self.list_layers.append(keras.layers.Input(shape=(input_dims+n_actions,)))
        for i in range(num_layers):
            self.list_layers.append(keras.layers.Dense(512,activation = 'relu'))
        self.list_layers.append(keras.layers.Dense(1))
        self.critic = keras.Sequential(self.list_layers)
    def call(self,state,action):
        Z = self.critic(tf.concat([state,action],axis = 1 ))
        return Z

# %%
class Agent(object):
    
    def __init__(self,memory_size,n_actions,action_bounds,input_dims,optimizers,gamma=0.999):
        self.action_bounds = action_bounds
        self.Actor_local = Actor(n_actions=n_actions,action_bounds= action_bounds,input_dims=input_dims)
        self.Actor_target = Actor(n_actions=n_actions,action_bounds= action_bounds,input_dims=input_dims)
        self.Critic_local = Critic(input_dims,n_actions)
        self.Critic_target = Critic(input_dims,n_actions)
        self.ReplayBuffer = ReplayBuffer(memory_size,input_dims,n_actions)
        self.actor_opt,self.critic_opt = optimizers
        self.Actor_local.compile(loss = 'mse',optimizer = self.actor_opt)
        self.Critic_local.compile(loss = 'mse',optimizer = self.critic_opt)
        self.h = tf.keras.losses.Huber()
        #self.noise = Noise()
        self.gamma = gamma
        
    def remember(self,exp):
        state,action,reward,next_state,done = exp
        self.ReplayBuffer.store_transition(state,action,reward,next_state,done )
    
    def choose_action(self,state,noise=True):
        action = self.Actor_local(state[np.newaxis]).numpy()[0]
        if noise:
            action+= np.random.normal(0,0.05)
        

        return np.clip(action,self.action_bounds[0],self.action_bounds[1])
    
    def soft_update(self,eta= 0.001):
        target_weights_actor = self.Actor_target.get_weights()
        local_weights_actor = self.Actor_local.get_weights()
        target_weights_critic = self.Critic_target.get_weights()
        local_weights_critic = self.Critic_local.get_weights()
        update_weights_actor = []
        update_weights_critic = []
        for i in range(len(target_weights_actor)):
            update_weights_actor.append((1-eta)*target_weights_actor[i]+eta*local_weights_actor[i])
        self.Actor_target.set_weights(update_weights_actor)
        for i in range(len(target_weights_critic)):
            update_weights_critic.append((1-eta)*target_weights_critic[i]+eta*local_weights_critic[i])
        self.Critic_target.set_weights(update_weights_critic)
        
        
    def learn(self,batch_size):
        exp = self.ReplayBuffer. sample_buffer(batch_size)
        states,actions,rewards,next_states,dones = exp 
        
        with tf.GradientTape() as tape_critic:
            next_actions = self.Actor_target(next_states)
            next_critic_values = tf.squeeze(self.Critic_target(next_states,next_actions),1)
            target_values = rewards + self.gamma*(1-dones)*next_critic_values
            critic_values = self.Critic_local(states,actions)
            loss_critic = self.h(target_values,critic_values)
        gradient_critic = tape_critic.gradient(loss_critic,self.Critic_local.trainable_variables)
        self.critic_opt.apply_gradients(zip(gradient_critic,self.Critic_local.trainable_variables))
        
        with tf.GradientTape() as tape_actor:
            critic_policy_actions = self.Actor_local(states)
            critic_policy_values = self.Critic_local(states,critic_policy_actions)
            actor_loss = -tf.reduce_mean(critic_policy_values)
            
        gradient_actor = tape_actor.gradient(actor_loss, self.Actor_local.trainable_variables)
        self.actor_opt.apply_gradients(zip(gradient_actor,self.Actor_local.trainable_variables))
        
        self.soft_update()

# %%
n_actions = 2
input_dims = env.observation_space.shape[0]
memory_size = 2000
action_bounds =(-1,1)
optimizers= (keras.optimizers.Adam(lr=1e-4),keras.optimizers.Adam(lr=1e-4))
batch_size = 64
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <module>
#       1 n_actions = 2
# ----> 2 input_dims = env.observation_space.shape[0]
#       3 memory_size = 2000
#       4 action_bounds =(-1,1)
#
# NameError: name 'env' is not defined

# %%
agent = Agent(memory_size,n_actions = n_actions,action_bounds = action_bounds,input_dims = input_dims,optimizers = optimizers)
# Out:
# 2022-02-07 22:45:05.925242: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-07 22:45:05.925840: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 22:45:05.925972: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-02-07 22:45:05.925998: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-02-07 22:45:05.926048: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-02-07 22:45:05.926060: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-02-07 22:45:05.926071: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-02-07 22:45:05.926081: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-02-07 22:45:05.926091: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-02-07 22:45:05.926101: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-02-07 22:45:05.926111: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-02-07 22:45:05.926168: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 22:45:05.926305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 22:45:05.926396: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-02-07 22:45:05.926421: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-02-07 22:45:06.321009: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-02-07 22:45:06.321038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-02-07 22:45:06.321043: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-02-07 22:45:06.321226: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 22:45:06.321414: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 22:45:06.321539: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-07 22:45:06.321645: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6976 MB memory) -> physical GPU (device: 0, name: Quadro RTX 4000, pci bus id: 0000:01:00.0, compute capability: 7.5)
# 2022-02-07 22:45:06.321852: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
done = False 
history = []
avg_score = 0
n_episodes = 1500



max_avg_score = 0
lr_step = 0
for ep in range(n_episodes):
    state = env.reset()
    score = 0
    done = False
    step =0
  
    while not done:
        lr_step+=1
        action = agent.choose_action(state)
        next_state,reward,done,info = env.step(action)
        score+=reward
        step+=1 
        exp = (state,action,reward,next_state,done)
        agent.remember(exp)
        state = next_state
        if ep>50: 
            agent.learn(batch_size)
   
    history.append(score)
    avg_score =  np.mean(history[-100:])
    if (ep>50) & (avg_score>=max_avg_score+10):
        max_avg_score = avg_score
        agent.Actor_local.actor.save('Actor_LunarLanderContinuous_1.hf5')
        agent.Critic_local.critic.save('Critic_LunarLanderContinuous_1.hf5')
        
        
    print('episode :', ep ,'score %.2f average_score %.2f  '%(score,avg_score))
# Out:
# episode : 0 score 177.61 average_score 177.61
# episode : 1 score -51.42 average_score 63.09
# episode : 2 score 236.05 average_score 120.75
# episode : 3 score 211.54 average_score 143.45
# episode : 4 score -34.31 average_score 107.89
# episode : 5 score 265.38 average_score 134.14
# episode : 6 score 167.94 average_score 138.97
# episode : 7 score 167.77 average_score 142.57
# episode : 8 score 125.66 average_score 140.69
# episode : 9 score 233.47 average_score 149.97
# episode : 10 score 230.53 average_score 157.29
# episode : 11 score 139.77 average_score 155.83
# episode : 12 score 244.81 average_score 162.68
# episode : 13 score 262.70 average_score 169.82
# episode : 14 score 276.22 average_score 176.91
# episode : 15 score 210.82 average_score 179.03
# episode : 16 score 4.56 average_score 168.77
# episode : 17 score 202.51 average_score 170.64
# episode : 18 score 157.21 average_score 169.94
# episode : 19 score 173.83 average_score 170.13
# episode : 20 score 198.56 average_score 171.49
# episode : 21 score -34.85 average_score 162.11
# episode : 22 score -30.46 average_score 153.73
# episode : 23 score 262.98 average_score 158.29
# episode : 24 score 189.17 average_score 159.52
# episode : 25 score 119.53 average_score 157.98
# episode : 26 score 242.85 average_score 161.13
# episode : 27 score 248.56 average_score 164.25
# episode : 28 score 212.87 average_score 165.93
# episode : 29 score 236.20 average_score 168.27
# episode : 30 score 280.80 average_score 171.90
# episode : 31 score 187.76 average_score 172.39
# episode : 32 score 286.36 average_score 175.85
# episode : 33 score 221.39 average_score 177.19
# episode : 34 score 300.01 average_score 180.70
# episode : 35 score 258.62 average_score 182.86
# episode : 36 score 262.46 average_score 185.01
# episode : 37 score 194.61 average_score 185.27
# episode : 38 score 201.03 average_score 185.67
# episode : 39 score 133.67 average_score 184.37
# episode : 40 score 261.57 average_score 186.25
# episode : 41 score 293.05 average_score 188.80
# episode : 42 score 238.02 average_score 189.94
# episode : 43 score 179.10 average_score 189.69
# episode : 44 score 284.71 average_score 191.81
# episode : 45 score 268.17 average_score 193.47
# episode : 46 score -51.00 average_score 188.26
# episode : 47 score 248.54 average_score 189.52
# episode : 48 score 216.58 average_score 190.07
# episode : 49 score 107.51 average_score 188.42
# episode : 50 score 253.19 average_score 189.69
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x7f657c25eee0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x7f657c25eee0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2022-02-08 09:12:24.836173: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: Actor_LunarLanderContinuous_1.hf5/assets
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x7f657c2075e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x7f657c2075e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# INFO:tensorflow:Assets written to: Critic_LunarLanderContinuous_1.hf5/assets
# episode : 51 score 220.82 average_score 190.29
# episode : 52 score 221.93 average_score 190.89
# episode : 53 score 205.24 average_score 191.15
# episode : 54 score 217.37 average_score 191.63
# episode : 55 score -242.31 average_score 183.88
# episode : 56 score 265.75 average_score 185.32
# episode : 57 score 68.23 average_score 183.30
# episode : 58 score 182.76 average_score 183.29
# episode : 59 score 91.68 average_score 181.76
# episode : 60 score 43.86 average_score 179.50
# episode : 61 score 55.95 average_score 177.51
# episode : 62 score 239.94 average_score 178.50
# episode : 63 score 260.50 average_score 179.78
# episode : 64 score 260.57 average_score 181.02
# episode : 65 score 251.07 average_score 182.08
# episode : 66 score 292.25 average_score 183.73
# episode : 67 score 233.09 average_score 184.45
# episode : 68 score 280.46 average_score 185.85
# episode : 69 score 271.18 average_score 187.07
# episode : 70 score 281.16 average_score 188.39
# episode : 71 score 292.45 average_score 189.84
# episode : 72 score 314.40 average_score 191.54
# episode : 73 score 249.86 average_score 192.33
# episode : 74 score 269.59 average_score 193.36
# episode : 75 score 27.26 average_score 191.17
# episode : 76 score 200.08 average_score 191.29
# episode : 77 score -5.46 average_score 188.77
# episode : 78 score 211.79 average_score 189.06
# episode : 79 score 13.22 average_score 186.86
# episode : 80 score 234.09 average_score 187.44
# episode : 81 score -61.04 average_score 184.41
# episode : 82 score -7.02 average_score 182.11
# episode : 83 score 220.78 average_score 182.57
# episode : 84 score -26.44 average_score 180.11
# episode : 85 score -7.45 average_score 177.93
# episode : 86 score 21.28 average_score 176.13
# episode : 87 score 292.90 average_score 177.45
# episode : 88 score 257.71 average_score 178.36
# episode : 89 score 104.50 average_score 177.54
# episode : 90 score 275.93 average_score 178.62
# episode : 91 score 45.94 average_score 177.17
# episode : 92 score 234.43 average_score 177.79
# episode : 93 score 4.09 average_score 175.94
# episode : 94 score 30.55 average_score 174.41
# episode : 95 score -3.57 average_score 172.56
# episode : 96 score 282.20 average_score 173.69
# episode : 97 score 259.96 average_score 174.57
# episode : 98 score 236.27 average_score 175.19
# episode : 99 score -6.77 average_score 173.37
# episode : 100 score -26.11 average_score 171.34
# episode : 101 score 245.12 average_score 174.30
# episode : 102 score 11.51 average_score 172.06
# episode : 103 score 202.36 average_score 171.96
# episode : 104 score 27.48 average_score 172.58
# episode : 105 score 278.99 average_score 172.72
# episode : 106 score 204.43 average_score 173.08
# episode : 107 score -8.34 average_score 171.32
# episode : 108 score 207.60 average_score 172.14
# episode : 109 score -288.73 average_score 166.92
# episode : 110 score 126.74 average_score 165.88
# episode : 111 score -12.45 average_score 164.36
# episode : 112 score 27.48 average_score 162.19
# episode : 113 score 265.25 average_score 162.21
# episode : 114 score 27.04 average_score 159.72
# episode : 115 score -11.39 average_score 157.50
# episode : 116 score 170.86 average_score 159.16
# episode : 117 score 280.81 average_score 159.94
# episode : 118 score 202.58 average_score 160.40
# episode : 119 score 307.10 average_score 161.73
# episode : 120 score -12.91 average_score 159.61
# episode : 121 score 266.03 average_score 162.62
# episode : 122 score 69.24 average_score 163.62
# episode : 123 score 199.45 average_score 162.99
# episode : 124 score -33.77 average_score 160.76
# episode : 125 score 189.30 average_score 161.45
# episode : 126 score -15.34 average_score 158.87
# episode : 127 score 212.22 average_score 158.51
# episode : 128 score -205.63 average_score 154.32
# episode : 129 score 258.12 average_score 154.54
# episode : 130 score 221.38 average_score 153.95
# episode : 131 score 24.98 average_score 152.32
# episode : 132 score 214.15 average_score 151.60
# episode : 133 score 270.63 average_score 152.09
# episode : 134 score -14.33 average_score 148.95
# episode : 135 score 262.99 average_score 148.99
# episode : 136 score 300.22 average_score 149.37
# episode : 137 score -244.37 average_score 144.98
# episode : 138 score 234.62 average_score 145.31
# episode : 139 score 268.96 average_score 146.67
# episode : 140 score 151.87 average_score 145.57
# episode : 141 score 284.39 average_score 145.48
# episode : 142 score 271.65 average_score 145.82
# episode : 143 score 253.05 average_score 146.56
# episode : 144 score 24.14 average_score 143.95
# episode : 145 score 209.83 average_score 143.37
# episode : 146 score 188.42 average_score 145.76
# episode : 147 score 46.29 average_score 143.74
# episode : 148 score 199.49 average_score 143.57
# episode : 149 score 25.58 average_score 142.75
# episode : 150 score 219.67 average_score 142.42
# episode : 151 score 239.15 average_score 142.60
# episode : 152 score 285.84 average_score 143.24
# episode : 153 score 218.98 average_score 143.38
# episode : 154 score 200.14 average_score 143.20
# episode : 155 score -104.14 average_score 144.59
# episode : 156 score 72.36 average_score 142.65
# episode : 157 score -382.37 average_score 138.15
# episode : 158 score 260.31 average_score 138.92
# episode : 159 score 285.57 average_score 140.86
# episode : 160 score 22.04 average_score 140.64
# episode : 161 score 205.78 average_score 142.14
# episode : 162 score 250.73 average_score 142.25
# episode : 163 score 233.22 average_score 141.98
# episode : 164 score 259.97 average_score 141.97
# episode : 165 score 269.29 average_score 142.15
# episode : 166 score 223.57 average_score 141.47
# episode : 167 score 220.35 average_score 141.34
# episode : 168 score 205.75 average_score 140.59
# episode : 169 score 193.83 average_score 139.82
# episode : 170 score 13.97 average_score 137.15
# episode : 171 score 228.12 average_score 136.50
# episode : 172 score -109.04 average_score 132.27
# episode : 173 score 243.23 average_score 132.20
# episode : 174 score 148.98 average_score 131.00
# episode : 175 score 254.52 average_score 133.27
# episode : 176 score 280.60 average_score 134.07
# episode : 177 score 240.91 average_score 136.54
# episode : 178 score 175.96 average_score 136.18
# episode : 179 score 238.30 average_score 138.43
# episode : 180 score -10.61 average_score 135.98
# episode : 181 score 224.79 average_score 138.84
# episode : 182 score 238.64 average_score 141.30
# episode : 183 score 156.54 average_score 140.65
# episode : 184 score 191.58 average_score 142.83
# episode : 185 score 155.85 average_score 144.47
# episode : 186 score 36.15 average_score 144.62
# episode : 187 score 50.59 average_score 142.19
# episode : 188 score -16.33 average_score 139.45
# episode : 189 score 61.83 average_score 139.03
# episode : 190 score -71.60 average_score 135.55
# episode : 191 score 170.70 average_score 136.80
# episode : 192 score 81.44 average_score 135.27
# episode : 193 score 193.73 average_score 137.17
# episode : 194 score 29.80 average_score 137.16
# episode : 195 score -3.20 average_score 137.16
# episode : 196 score 180.70 average_score 136.15
# episode : 197 score -266.35 average_score 130.88
# episode : 198 score 30.55 average_score 128.83
# episode : 199 score 3.98 average_score 128.93
# episode : 200 score 18.12 average_score 129.38
# episode : 201 score -27.84 average_score 126.65
# episode : 202 score -0.33 average_score 126.53
# episode : 203 score 9.02 average_score 124.59
# episode : 204 score -38.52 average_score 123.94
# episode : 205 score -37.21 average_score 120.77
# episode : 206 score -1.73 average_score 118.71
# episode : 207 score -19.06 average_score 118.60
# episode : 208 score 33.60 average_score 116.86
# episode : 209 score 7.37 average_score 119.83
# episode : 210 score 14.66 average_score 118.70
# episode : 211 score -41.55 average_score 118.41
# episode : 212 score 11.25 average_score 118.25
# episode : 213 score 20.28 average_score 115.80
# episode : 214 score 230.01 average_score 117.83
# episode : 215 score 30.66 average_score 118.25
# episode : 216 score -3.83 average_score 116.50
# episode : 217 score 3.58 average_score 113.73
# episode : 218 score -4.53 average_score 111.66
# episode : 219 score 12.28 average_score 108.71
# episode : 220 score 273.76 average_score 111.58
# episode : 221 score 17.73 average_score 109.10
# episode : 222 score 57.26 average_score 108.98
# episode : 223 score -23.61 average_score 106.75
# episode : 224 score -37.72 average_score 106.71
# episode : 225 score -25.64 average_score 104.56
# episode : 226 score -31.75 average_score 104.39
# episode : 227 score 174.09 average_score 104.01
# episode : 228 score -1.36 average_score 106.05
# episode : 229 score -75.34 average_score 102.72
# episode : 230 score -8.47 average_score 100.42
# episode : 231 score 229.91 average_score 102.47
# episode : 232 score 10.79 average_score 100.44
# episode : 233 score -48.15 average_score 97.25
# episode : 234 score 11.84 average_score 97.51
# episode : 235 score -53.85 average_score 94.34
# episode : 236 score 3.10 average_score 91.37
# episode : 237 score 5.55 average_score 93.87
# episode : 238 score 148.19 average_score 93.01
# episode : 239 score -66.45 average_score 89.65
# episode : 240 score -46.72 average_score 87.67
# episode : 241 score 123.12 average_score 86.05
# episode : 242 score 209.81 average_score 85.44
# episode : 243 score 190.60 average_score 84.81
# episode : 244 score -46.76 average_score 84.10
# episode : 245 score -113.01 average_score 80.87
# episode : 246 score 185.21 average_score 80.84
# episode : 247 score -60.28 average_score 79.78
# episode : 248 score -64.85 average_score 77.13
# episode : 249 score 210.08 average_score 78.98
# episode : 250 score -49.06 average_score 76.29
# episode : 251 score -38.82 average_score 73.51
# episode : 252 score -9.37 average_score 70.56
# episode : 253 score -72.65 average_score 67.64
# episode : 254 score -58.83 average_score 65.05
# episode : 255 score -14.80 average_score 65.95
# episode : 256 score -107.76 average_score 64.14
# episode : 257 score -269.53 average_score 65.27
# episode : 258 score -142.30 average_score 61.25
# episode : 259 score -6.94 average_score 58.32
# episode : 260 score -170.19 average_score 56.40
# episode : 261 score -38.69 average_score 53.95
# episode : 262 score -18.50 average_score 51.26
# episode : 263 score -12.43 average_score 48.81
# episode : 264 score -12.38 average_score 46.08
# episode : 265 score -188.16 average_score 41.51
# episode : 266 score 153.61 average_score 40.81
# episode : 267 score -116.41 average_score 37.44
# episode : 268 score 22.48 average_score 35.61
# episode : 269 score -197.89 average_score 31.69
# episode : 270 score -175.96 average_score 29.79
# episode : 271 score -67.79 average_score 26.83
# episode : 272 score -236.65 average_score 25.56
# episode : 273 score -270.53 average_score 20.42
# episode : 274 score -19.26 average_score 18.74
# episode : 275 score -110.71 average_score 15.08
# episode : 276 score -41.73 average_score 11.86
# episode : 277 score -205.88 average_score 7.39
# episode : 278 score -88.82 average_score 4.74
# episode : 279 score 12.55 average_score 2.49
# episode : 280 score -169.00 average_score 0.90
# episode : 281 score -73.49 average_score -2.08
# episode : 282 score -105.48 average_score -5.52
# episode : 283 score -70.10 average_score -7.79
# episode : 284 score -14.56 average_score -9.85
# episode : 285 score -104.95 average_score -12.46
# episode : 286 score -78.67 average_score -13.61
# episode : 287 score -61.22 average_score -14.72
# episode : 288 score -121.60 average_score -15.78
# episode : 289 score -52.31 average_score -16.92
# episode : 290 score -106.31 average_score -17.26
# episode : 291 score -157.81 average_score -20.55
# episode : 292 score -60.87 average_score -21.97
# episode : 293 score -335.79 average_score -27.27
# episode : 294 score 2.62 average_score -27.54
# episode : 295 score 84.04 average_score -26.67
# episode : 296 score -217.77 average_score -30.65
# episode : 297 score -111.47 average_score -29.10
# episode : 298 score -47.66 average_score -29.89
# episode : 299 score -179.27 average_score -31.72
# episode : 300 score -311.74 average_score -35.02
# episode : 301 score -196.57 average_score -36.70
# episode : 302 score -81.33 average_score -37.51
# episode : 303 score -155.90 average_score -39.16
# episode : 304 score -79.24 average_score -39.57
# episode : 305 score -55.60 average_score -39.75
# episode : 306 score -200.24 average_score -41.74
# episode : 307 score -302.72 average_score -44.58
# episode : 308 score 11.27 average_score -44.80
# episode : 309 score -301.85 average_score -47.89
# episode : 310 score -180.09 average_score -49.84
# episode : 311 score -262.04 average_score -52.04
# episode : 312 score -42.34 average_score -52.58
# episode : 313 score -265.25 average_score -55.44
# episode : 314 score -241.07 average_score -60.15
# episode : 315 score 19.92 average_score -60.25
# episode : 316 score -236.80 average_score -62.58
# episode : 317 score -198.53 average_score -64.60
# episode : 318 score -72.12 average_score -65.28
# episode : 319 score 26.53 average_score -65.14
# episode : 320 score -42.07 average_score -68.30
# episode : 321 score -354.15 average_score -72.01
# episode : 322 score -93.08 average_score -73.52
# episode : 323 score -229.05 average_score -75.57
# episode : 324 score 30.23 average_score -74.89
# episode : 325 score 12.80 average_score -74.51
# episode : 326 score -34.69 average_score -74.54
# episode : 327 score -12.40 average_score -76.40
# episode : 328 score -1.23 average_score -76.40
# episode : 329 score -2.41 average_score -75.67
# episode : 330 score -227.23 average_score -77.86
# episode : 331 score -217.78 average_score -82.34
# episode : 332 score 10.99 average_score -82.33
# episode : 333 score -226.24 average_score -84.12
# episode : 334 score -63.24 average_score -84.87
# episode : 335 score -193.63 average_score -86.26
# episode : 336 score -133.24 average_score -87.63
# episode : 337 score -7.98 average_score -87.76
# episode : 338 score 27.86 average_score -88.97
# episode : 339 score -24.45 average_score -88.55
# episode : 340 score 17.81 average_score -87.90
# episode : 341 score -12.31 average_score -89.26
# episode : 342 score -116.40 average_score -92.52
# episode : 343 score 9.29 average_score -94.33
# episode : 344 score 27.29 average_score -93.59
# episode : 345 score -237.95 average_score -94.84
# episode : 346 score -35.09 average_score -97.04
# episode : 347 score 7.58 average_score -96.36
# episode : 348 score -7.87 average_score -95.79
# episode : 349 score -10.53 average_score -98.00
# episode : 350 score -111.75 average_score -98.63
# episode : 351 score -118.12 average_score -99.42
# episode : 352 score -24.23 average_score -99.57
# episode : 353 score -19.30 average_score -99.03
# episode : 354 score -14.80 average_score -98.59
# episode : 355 score -0.58 average_score -98.45
# episode : 356 score -48.04 average_score -97.86
# episode : 357 score -68.08 average_score -95.84
# episode : 358 score -14.15 average_score -94.56
# episode : 359 score -51.37 average_score -95.00
# episode : 360 score -0.76 average_score -93.31
# episode : 361 score -46.91 average_score -93.39
# episode : 362 score -61.13 average_score -93.82
# episode : 363 score -37.71 average_score -94.07
# episode : 364 score -370.50 average_score -97.65
# episode : 365 score -13.96 average_score -95.91
# episode : 366 score -50.11 average_score -97.95
# episode : 367 score 21.82 average_score -96.56
# episode : 368 score -8.97 average_score -96.88
# episode : 369 score 157.39 average_score -93.33
# episode : 370 score -213.23 average_score -93.70
# episode : 371 score -88.32 average_score -93.90
# episode : 372 score -100.57 average_score -92.54
# episode : 373 score -96.32 average_score -90.80
# episode : 374 score -93.88 average_score -91.55
# episode : 375 score -62.40 average_score -91.06
# episode : 376 score -91.65 average_score -91.56
# episode : 377 score -179.02 average_score -91.29
# episode : 378 score -185.38 average_score -92.26
# episode : 379 score -190.82 average_score -94.29
# episode : 380 score -181.52 average_score -94.42
# episode : 381 score -206.04 average_score -95.74
# episode : 382 score -222.14 average_score -96.91
# episode : 383 score -276.42 average_score -98.97
# episode : 384 score -61.37 average_score -99.44
# episode : 385 score -200.31 average_score -100.40
# episode : 386 score 224.77 average_score -97.36
# episode : 387 score -137.65 average_score -98.13
# episode : 388 score 45.32 average_score -96.46
# episode : 389 score -204.83 average_score -97.98
# episode : 390 score -178.72 average_score -98.71
# episode : 391 score -201.70 average_score -99.15
# episode : 392 score 55.67 average_score -97.98
# episode : 393 score -306.67 average_score -97.69
# episode : 394 score -346.89 average_score -101.18
# episode : 395 score 10.86 average_score -101.92
# episode : 396 score -24.39 average_score -99.98
# episode : 397 score -55.14 average_score -99.42
# episode : 398 score 3.32 average_score -98.91
# episode : 399 score 4.45 average_score -97.07
# episode : 400 score -40.92 average_score -94.36
# episode : 401 score -10.40 average_score -92.50
# episode : 402 score -200.41 average_score -93.69
# episode : 403 score -182.95 average_score -93.96
# episode : 404 score 0.26 average_score -93.17
# episode : 405 score -30.67 average_score -92.92
# episode : 406 score -173.38 average_score -92.65
# episode : 407 score 37.82 average_score -89.24
# episode : 408 score 184.68 average_score -87.51
# episode : 409 score -8.21 average_score -84.57
# episode : 410 score 275.11 average_score -80.02
# episode : 411 score 233.29 average_score -75.07
# episode : 412 score -41.06 average_score -75.06
# episode : 413 score 109.19 average_score -71.31
# episode : 414 score 37.94 average_score -68.52
# episode : 415 score 292.56 average_score -65.79
# episode : 416 score -90.27 average_score -64.33
# episode : 417 score -172.22 average_score -64.07
# episode : 418 score 287.61 average_score -60.47
# episode : 419 score 283.12 average_score -57.90
# episode : 420 score 15.20 average_score -57.33
# episode : 421 score 238.79 average_score -51.40
# episode : 422 score 254.02 average_score -47.93
# episode : 423 score -27.87 average_score -45.92
# episode : 424 score -46.02 average_score -46.68
# episode : 425 score -158.39 average_score -48.39
# episode : 426 score 22.82 average_score -47.82
# episode : 427 score 5.67 average_score -47.64
# episode : 428 score 10.01 average_score -47.52
# episode : 429 score -5.26 average_score -47.55
# episode : 430 score 33.30 average_score -44.95
# episode : 431 score -353.22 average_score -46.30
# episode : 432 score 288.56 average_score -43.53
# episode : 433 score 65.48 average_score -40.61
# episode : 434 score 160.78 average_score -38.37
# episode : 435 score 244.15 average_score -33.99
# episode : 436 score -37.37 average_score -33.03
# episode : 437 score 7.97 average_score -32.87
# episode : 438 score 276.37 average_score -30.39
# episode : 439 score -67.37 average_score -30.82
# episode : 440 score 32.26 average_score -30.67
# episode : 441 score 63.06 average_score -29.92
# episode : 442 score 29.14 average_score -28.46
# episode : 443 score -51.96 average_score -29.08
# episode : 444 score 19.33 average_score -29.16
# episode : 445 score 214.25 average_score -24.63
# episode : 446 score 13.42 average_score -24.15
# episode : 447 score 15.48 average_score -24.07
# episode : 448 score 46.54 average_score -23.52
# episode : 449 score -18.48 average_score -23.60
# episode : 450 score 35.41 average_score -22.13
# episode : 451 score 11.02 average_score -20.84
# episode : 452 score 24.70 average_score -20.35
# episode : 453 score 17.20 average_score -19.99
# episode : 454 score 38.28 average_score -19.46
# episode : 455 score 221.17 average_score -17.24
# episode : 456 score 25.90 average_score -16.50
# episode : 457 score 30.80 average_score -15.51
# episode : 458 score 25.58 average_score -15.11
# episode : 459 score 22.94 average_score -14.37
# episode : 460 score -629.05 average_score -20.65
# episode : 461 score 31.83 average_score -19.87
# episode : 462 score 27.12 average_score -18.98
# episode : 463 score 45.57 average_score -18.15
# episode : 464 score 33.94 average_score -14.11
# episode : 465 score 27.90 average_score -13.69
# episode : 466 score 63.81 average_score -12.55
# episode : 467 score -6.81 average_score -12.83
# episode : 468 score 236.26 average_score -10.38
# episode : 469 score -196.12 average_score -13.92
# episode : 470 score 289.72 average_score -8.89
# episode : 471 score 57.04 average_score -7.43
# episode : 472 score 20.89 average_score -6.22
# episode : 473 score -165.10 average_score -6.91
# episode : 474 score 220.24 average_score -3.77
# episode : 475 score 11.52 average_score -3.03
# episode : 476 score 20.16 average_score -1.91
# episode : 477 score 54.15 average_score 0.42
# episode : 478 score 257.74 average_score 4.85
# episode : 479 score 26.70 average_score 7.03
# episode : 480 score 38.66 average_score 9.23
# episode : 481 score 28.11 average_score 11.57
# episode : 482 score 39.25 average_score 14.19
# episode : 483 score 62.99 average_score 17.58
# episode : 484 score -21.89 average_score 17.97
# episode : 485 score 242.46 average_score 22.40
# episode : 486 score 17.32 average_score 20.33
# episode : 487 score 44.27 average_score 22.15
# episode : 488 score 18.98 average_score 21.88
# episode : 489 score -177.84 average_score 22.15
# episode : 490 score 19.35 average_score 24.13
# episode : 491 score 255.74 average_score 28.71
# episode : 492 score -467.97 average_score 23.47
# episode : 493 score 297.48 average_score 29.51
# episode : 494 score 42.33 average_score 33.41
# episode : 495 score -578.84 average_score 27.51
# episode : 496 score 49.44 average_score 28.25
# episode : 497 score 253.35 average_score 31.33
# episode : 498 score 31.03 average_score 31.61
# episode : 499 score 248.49 average_score 34.05
# episode : 500 score 200.77 average_score 36.47
# episode : 501 score 195.64 average_score 38.53
# episode : 502 score -40.16 average_score 40.13
# episode : 503 score 265.81 average_score 44.62
# episode : 504 score -107.69 average_score 43.54
# episode : 505 score -826.23 average_score 35.58
# episode : 506 score -168.89 average_score 35.63
# episode : 507 score 24.79 average_score 35.50
# episode : 508 score -483.99 average_score 28.81
# episode : 509 score -253.39 average_score 26.36
# episode : 510 score -577.98 average_score 17.83
# episode : 511 score 215.50 average_score 17.65
# episode : 512 score -435.02 average_score 13.71
# episode : 513 score -45.47 average_score 12.16
# episode : 514 score -37.11 average_score 11.41
# episode : 515 score -170.51 average_score 6.78
# episode : 516 score -452.41 average_score 3.16
# episode : 517 score 251.53 average_score 7.40
# episode : 518 score -326.42 average_score 1.26
# episode : 519 score 230.32 average_score 0.73
# episode : 520 score -223.42 average_score -1.66
# episode : 521 score -195.68 average_score -6.00
# episode : 522 score -395.38 average_score -12.50
# episode : 523 score -711.21 average_score -19.33
# episode : 524 score -227.84 average_score -21.15
# episode : 525 score -216.46 average_score -21.73
# episode : 526 score -205.02 average_score -24.01
# episode : 527 score -194.86 average_score -26.01
# episode : 528 score -309.31 average_score -29.20
# episode : 529 score -242.55 average_score -31.58
# episode : 530 score 76.56 average_score -31.14
# episode : 531 score -248.55 average_score -30.10
# episode : 532 score -237.26 average_score -35.36
# episode : 533 score -473.95 average_score -40.75
# episode : 534 score -207.75 average_score -44.44
# episode : 535 score -518.68 average_score -52.06
# episode : 536 score -485.21 average_score -56.54
# episode : 537 score -436.42 average_score -60.99
# episode : 538 score -552.23 average_score -69.27
# episode : 539 score -491.53 average_score -73.51
# episode : 540 score -498.01 average_score -78.82
# episode : 541 score -362.60 average_score -83.07
# episode : 542 score -546.17 average_score -88.83
# episode : 543 score -553.44 average_score -93.84
# episode : 544 score -486.12 average_score -98.90
# episode : 545 score -499.22 average_score -106.03
# episode : 546 score -286.66 average_score -109.03
# episode : 547 score -482.70 average_score -114.01
# episode : 548 score -294.80 average_score -117.43
# episode : 549 score -421.17 average_score -121.45
# episode : 550 score -279.08 average_score -124.60
# episode : 551 score -333.22 average_score -128.04
# episode : 552 score -465.16 average_score -132.94
# episode : 553 score -472.93 average_score -137.84
# episode : 554 score -460.53 average_score -142.83
# episode : 555 score -469.30 average_score -149.73
# episode : 556 score -399.96 average_score -153.99
# episode : 557 score -424.47 average_score -158.54
# episode : 558 score -399.14 average_score -162.79
# episode : 559 score -271.35 average_score -165.73
# episode : 560 score -593.65 average_score -165.38
# episode : 561 score -311.46 average_score -168.81
# episode : 562 score -278.85 average_score -171.87
# episode : 563 score -264.67 average_score -174.98
# episode : 564 score -478.87 average_score -180.10
# episode : 565 score -507.95 average_score -185.46
# episode : 566 score -385.84 average_score -189.96
# episode : 567 score -313.50 average_score -193.03
# episode : 568 score -482.18 average_score -200.21
# episode : 569 score -252.37 average_score -200.77
# episode : 570 score -454.90 average_score -208.22
# episode : 571 score -537.01 average_score -214.16
# episode : 572 score -481.28 average_score -219.18
# episode : 573 score -430.72 average_score -221.84
# episode : 574 score -423.19 average_score -228.27
# episode : 575 score -437.96 average_score -232.77
# episode : 576 score -453.38 average_score -237.50
# episode : 577 score -461.81 average_score -242.66
# episode : 578 score -438.21 average_score -249.62
# episode : 579 score -656.56 average_score -256.45
# episode : 580 score -354.58 average_score -260.39
# episode : 581 score -423.60 average_score -264.90
# episode : 582 score -376.20 average_score -269.06
# episode : 583 score -451.16 average_score -274.20
# episode : 584 score -374.77 average_score -277.73
# episode : 585 score -449.89 average_score -284.65
# episode : 586 score -396.53 average_score -288.79
# episode : 587 score -370.71 average_score -292.94
# episode : 588 score -408.94 average_score -297.22
# episode : 589 score -502.76 average_score -300.47
# episode : 590 score -430.89 average_score -304.97
# episode : 591 score -359.00 average_score -311.12
# episode : 592 score -376.56 average_score -310.20
# episode : 593 score -473.17 average_score -317.91
# episode : 594 score -610.05 average_score -324.43
# episode : 595 score -342.84 average_score -322.07
# episode : 596 score -336.96 average_score -325.94
# episode : 597 score -398.28 average_score -332.45
# episode : 598 score -427.17 average_score -337.04
# episode : 599 score -550.99 average_score -345.03
# episode : 600 score -330.82 average_score -350.35
# episode : 601 score -354.80 average_score -355.85
# episode : 602 score -329.31 average_score -358.74
# episode : 603 score -303.97 average_score -364.44
# episode : 604 score -248.02 average_score -365.84
# episode : 605 score -443.48 average_score -362.02
# episode : 606 score -406.60 average_score -364.39
# episode : 607 score -355.22 average_score -368.19
# episode : 608 score -368.00 average_score -367.03
# episode : 609 score -365.92 average_score -368.16
# episode : 610 score -341.03 average_score -365.79
# episode : 611 score -313.86 average_score -371.08
# episode : 612 score -410.37 average_score -370.84
# episode : 613 score -347.30 average_score -373.85
# episode : 614 score -362.68 average_score -377.11
# episode : 615 score -373.53 average_score -379.14
# episode : 616 score -450.46 average_score -379.12
# episode : 617 score -475.88 average_score -386.40
# episode : 618 score -442.64 average_score -387.56
# episode : 619 score -334.36 average_score -393.20
# episode : 620 score -693.00 average_score -397.90
# episode : 621 score -390.65 average_score -399.85
# episode : 622 score -372.15 average_score -399.62
# episode : 623 score -302.08 average_score -395.53
# episode : 624 score -463.57 average_score -397.88
# episode : 625 score -464.78 average_score -400.37
# episode : 626 score -380.70 average_score -402.12
# episode : 627 score -422.42 average_score -404.40
# episode : 628 score -393.31 average_score -405.24
# episode : 629 score -424.05 average_score -407.05
# episode : 630 score -371.47 average_score -411.53
# episode : 631 score -428.28 average_score -413.33
# episode : 632 score 35.33 average_score -410.61
# episode : 633 score -488.57 average_score -410.75
# episode : 634 score -351.57 average_score -412.19
# episode : 635 score -442.09 average_score -411.42
# episode : 636 score -494.64 average_score -411.52
# episode : 637 score -455.55 average_score -411.71
# episode : 638 score -503.35 average_score -411.22
# episode : 639 score -421.21 average_score -410.52
# episode : 640 score -476.28 average_score -410.30
# episode : 641 score -424.38 average_score -410.92
# episode : 642 score -474.94 average_score -410.21
# episode : 643 score -394.33 average_score -408.61
# episode : 644 score -340.12 average_score -407.15
# episode : 645 score -437.22 average_score -406.53
# episode : 646 score -487.27 average_score -408.54
# episode : 647 score -447.53 average_score -408.19
# episode : 648 score -412.78 average_score -409.37
# episode : 649 score -320.31 average_score -408.36
# episode : 650 score -483.77 average_score -410.41
# episode : 651 score -536.77 average_score -412.44
# episode : 652 score -362.65 average_score -411.42
# episode : 653 score -451.33 average_score -411.20
# episode : 654 score -562.13 average_score -412.22
# episode : 655 score -435.23 average_score -411.88
# episode : 656 score -358.08 average_score -411.46
# episode : 657 score -331.46 average_score -410.53
# episode : 658 score -516.96 average_score -411.71
# episode : 659 score -487.50 average_score -413.87
# episode : 660 score -497.35 average_score -412.90
# episode : 661 score -464.25 average_score -414.43
# episode : 662 score -533.44 average_score -416.98
# episode : 663 score -506.47 average_score -419.40
# episode : 664 score -446.62 average_score -419.07
# episode : 665 score -502.54 average_score -419.02
# episode : 666 score -515.00 average_score -420.31
# episode : 667 score -605.11 average_score -423.23
# episode : 668 score -390.62 average_score -422.31
# episode : 669 score -330.35 average_score -423.09
# episode : 670 score -544.14 average_score -423.98
# episode : 671 score -349.69 average_score -422.11
# episode : 672 score -561.37 average_score -422.91
# episode : 673 score -344.56 average_score -422.05
# episode : 674 score -419.49 average_score -422.01
# episode : 675 score -508.05 average_score -422.71
# episode : 676 score -560.21 average_score -423.78
# episode : 677 score -480.34 average_score -423.97
# episode : 678 score -575.12 average_score -425.34
# episode : 679 score -524.35 average_score -424.02
# episode : 680 score -553.69 average_score -426.01
# episode : 681 score -608.56 average_score -427.86
# episode : 682 score -549.14 average_score -429.59
# episode : 683 score -457.91 average_score -429.65
# episode : 684 score -550.81 average_score -431.41
# episode : 685 score -543.75 average_score -432.35
# episode : 686 score -538.58 average_score -433.77
# episode : 687 score -372.71 average_score -433.79
# episode : 688 score -400.02 average_score -433.70
# episode : 689 score -344.27 average_score -432.12
# episode : 690 score -436.88 average_score -432.18
# episode : 691 score -576.14 average_score -434.35
# episode : 692 score -351.96 average_score -434.10
# episode : 693 score -429.46 average_score -433.67
# episode : 694 score -546.72 average_score -433.03
# episode : 695 score -367.88 average_score -433.28
# episode : 696 score -524.77 average_score -435.16
# episode : 697 score -541.99 average_score -436.60
# episode : 698 score -355.04 average_score -435.88
# episode : 699 score -484.68 average_score -435.21
# episode : 700 score -410.81 average_score -436.01
# episode : 701 score -584.67 average_score -438.31
# episode : 702 score -559.88 average_score -440.62
# episode : 703 score -440.37 average_score -441.98
# episode : 704 score -365.72 average_score -443.16
# episode : 705 score -315.37 average_score -441.88
# episode : 706 score -306.20 average_score -440.87
# episode : 707 score -394.05 average_score -441.26
# episode : 708 score -578.72 average_score -443.37
# episode : 709 score -510.48 average_score -444.82
# episode : 710 score -520.76 average_score -446.61
# episode : 711 score -464.25 average_score -448.12
# episode : 712 score -346.69 average_score -447.48
# episode : 713 score -386.08 average_score -447.87
# episode : 714 score -560.34 average_score -449.84
# episode : 715 score -405.10 average_score -450.16
# episode : 716 score -594.32 average_score -451.60
# episode : 717 score -419.21 average_score -451.03
# episode : 718 score -465.18 average_score -451.26
# episode : 719 score -558.69 average_score -453.50
# episode : 720 score -490.86 average_score -451.48
# episode : 721 score -609.97 average_score -453.67
# episode : 722 score -395.85 average_score -453.91
# episode : 723 score -418.15 average_score -455.07
# episode : 724 score -544.51 average_score -455.88
# episode : 725 score -539.37 average_score -456.63
# episode : 726 score -626.53 average_score -459.08
# episode : 727 score -377.81 average_score -458.64
# episode : 728 score -506.38 average_score -459.77
# episode : 729 score -413.38 average_score -459.66
# episode : 730 score -337.97 average_score -459.33
# episode : 731 score -556.22 average_score -460.61
# episode : 732 score -572.03 average_score -466.68
# episode : 733 score -612.06 average_score -467.91
# episode : 734 score -485.85 average_score -469.26
# episode : 735 score -576.16 average_score -470.60
# episode : 736 score -594.40 average_score -471.60
# episode : 737 score -546.89 average_score -472.51
# episode : 738 score -583.59 average_score -473.31
# episode : 739 score -552.05 average_score -474.62
# episode : 740 score -457.21 average_score -474.43
# episode : 741 score -352.93 average_score -473.71
# episode : 742 score -440.44 average_score -473.37
# episode : 743 score -440.99 average_score -473.84
# episode : 744 score -481.22 average_score -475.25
# episode : 745 score -373.31 average_score -474.61
# episode : 746 score -556.26 average_score -475.30
# episode : 747 score -543.12 average_score -476.25
# episode : 748 score -545.34 average_score -477.58
# episode : 749 score -562.65 average_score -480.00
# episode : 750 score -435.17 average_score -479.52
# episode : 751 score -403.61 average_score -478.19
# episode : 752 score -551.54 average_score -480.07
# episode : 753 score -397.17 average_score -479.53
# episode : 754 score -590.94 average_score -479.82
# episode : 755 score -353.15 average_score -479.00
# episode : 756 score -593.06 average_score -481.35
# episode : 757 score -521.21 average_score -483.25
# episode : 758 score -563.96 average_score -483.72
# episode : 759 score -548.66 average_score -484.33
# episode : 760 score -548.34 average_score -484.84
# episode : 761 score -368.72 average_score -483.88
# episode : 762 score -454.01 average_score -483.09
# episode : 763 score -366.43 average_score -481.69
# episode : 764 score -542.83 average_score -482.65
# episode : 765 score -518.39 average_score -482.81
# episode : 766 score -402.23 average_score -481.68
# episode : 767 score -413.41 average_score -479.76
# episode : 768 score -478.97 average_score -480.65
# episode : 769 score -398.23 average_score -481.33
# episode : 770 score -478.70 average_score -480.67
# episode : 771 score -622.92 average_score -483.41
# episode : 772 score -529.37 average_score -483.09
# episode : 773 score -560.90 average_score -485.25
# episode : 774 score -448.65 average_score -485.54
# episode : 775 score -553.89 average_score -486.00
# episode : 776 score -589.00 average_score -486.29
# episode : 777 score -483.05 average_score -486.31
# episode : 778 score -376.28 average_score -484.33
# episode : 779 score -557.64 average_score -484.66
# episode : 780 score -369.43 average_score -482.82
# episode : 781 score -576.10 average_score -482.49
# episode : 782 score -393.38 average_score -480.93
# episode : 783 score -615.75 average_score -482.51
# episode : 784 score -475.49 average_score -481.76
# episode : 785 score -439.32 average_score -480.71
# episode : 786 score -451.03 average_score -479.84
# episode : 787 score -530.76 average_score -481.42
# episode : 788 score -422.12 average_score -481.64
# episode : 789 score -484.81 average_score -483.05
# episode : 790 score -519.55 average_score -483.87
# episode : 791 score -596.24 average_score -484.07
# episode : 792 score -425.81 average_score -484.81
# episode : 793 score -616.10 average_score -486.68
# episode : 794 score -601.87 average_score -487.23
# episode : 795 score -473.57 average_score -488.29
# episode : 796 score -431.74 average_score -487.36
# episode : 797 score -593.13 average_score -487.87
# episode : 798 score -563.90 average_score -489.96
# episode : 799 score -538.64 average_score -490.50
# episode : 800 score -666.58 average_score -493.05
# episode : 801 score -419.38 average_score -491.40
# episode : 802 score -410.20 average_score -489.90
# episode : 803 score -484.46 average_score -490.35
# episode : 804 score -435.75 average_score -491.05
# episode : 805 score -593.69 average_score -493.83
# episode : 806 score -553.36 average_score -496.30
# episode : 807 score -394.77 average_score -496.31
# episode : 808 score -518.11 average_score -495.70
# episode : 809 score -372.03 average_score -494.32
# episode : 810 score -619.94 average_score -495.31
# episode : 811 score -616.46 average_score -496.83
# episode : 812 score -614.51 average_score -499.51
# episode : 813 score -477.14 average_score -500.42
# episode : 814 score -377.23 average_score -498.59
# episode : 815 score -447.80 average_score -499.02
# episode : 816 score -560.23 average_score -498.67
# episode : 817 score -654.42 average_score -501.03
# episode : 818 score -381.61 average_score -500.19
# episode : 819 score -495.92 average_score -499.56
# episode : 820 score -488.88 average_score -499.54
# episode : 821 score -499.10 average_score -498.43
# episode : 822 score -509.95 average_score -499.58
# episode : 823 score -627.69 average_score -501.67
# episode : 824 score -462.15 average_score -500.85
# episode : 825 score -584.29 average_score -501.30
# episode : 826 score -620.28 average_score -501.23
# episode : 827 score -656.51 average_score -504.02
# episode : 828 score -596.83 average_score -504.93
# episode : 829 score -379.59 average_score -504.59
# episode : 830 score -593.78 average_score -507.15
# episode : 831 score -465.93 average_score -506.24
# episode : 832 score -573.06 average_score -506.25
# episode : 833 score -517.86 average_score -505.31
# episode : 834 score -443.70 average_score -504.89
# episode : 835 score -457.71 average_score -503.71
# episode : 836 score -444.62 average_score -502.21
# episode : 837 score -717.18 average_score -503.91
# episode : 838 score -552.00 average_score -503.59
# episode : 839 score -547.77 average_score -503.55
# episode : 840 score -614.60 average_score -505.13
# episode : 841 score -639.56 average_score -507.99
# episode : 842 score -568.20 average_score -509.27
# episode : 843 score -584.54 average_score -510.70
# episode : 844 score -438.94 average_score -510.28
# episode : 845 score -416.04 average_score -510.71
# episode : 846 score -543.41 average_score -510.58
# episode : 847 score -406.31 average_score -509.21
# episode : 848 score -630.28 average_score -510.06
# episode : 849 score -684.33 average_score -511.28
# episode : 850 score -628.59 average_score -513.21
# episode : 851 score -583.47 average_score -515.01
# episode : 852 score -514.05 average_score -514.64
# episode : 853 score -535.93 average_score -516.02
# episode : 854 score -593.61 average_score -516.05
# episode : 855 score -447.34 average_score -516.99
# episode : 856 score -439.49 average_score -515.46
# episode : 857 score -654.18 average_score -516.79
# episode : 858 score -674.49 average_score -517.89
# episode : 859 score -504.77 average_score -517.45
# episode : 860 score -439.38 average_score -516.36
# episode : 861 score -494.85 average_score -517.62
# episode : 862 score -676.46 average_score -519.85
# episode : 863 score -518.13 average_score -521.37
# episode : 864 score -686.58 average_score -522.80
# episode : 865 score -588.21 average_score -523.50
# episode : 866 score -542.43 average_score -524.90
# episode : 867 score -501.15 average_score -525.78
# episode : 868 score -520.72 average_score -526.20
# episode : 869 score -470.03 average_score -526.92
# episode : 870 score -417.87 average_score -526.31
# episode : 871 score -679.52 average_score -526.87
# episode : 872 score -616.52 average_score -527.75
# episode : 873 score -532.24 average_score -527.46
# episode : 874 score -488.05 average_score -527.85
# episode : 875 score -623.46 average_score -528.55
# episode : 876 score -658.25 average_score -529.24
# episode : 877 score -429.76 average_score -528.71
# episode : 878 score -379.29 average_score -528.74
# episode : 879 score -596.00 average_score -529.12
# episode : 880 score -423.19 average_score -529.66
# episode : 881 score -425.86 average_score -528.16
# episode : 882 score -581.93 average_score -530.04
# episode : 883 score -452.68 average_score -528.41
# episode : 884 score -640.40 average_score -530.06
# episode : 885 score -642.40 average_score -532.09
# episode : 886 score -486.87 average_score -532.45
# episode : 887 score -400.25 average_score -531.15
# episode : 888 score -635.37 average_score -533.28
# episode : 889 score -356.83 average_score -532.00
# episode : 890 score -603.13 average_score -532.83
# episode : 891 score -440.12 average_score -531.27
# episode : 892 score -599.25 average_score -533.01
# episode : 893 score -496.61 average_score -531.81
# episode : 894 score -634.78 average_score -532.14
# episode : 895 score -367.77 average_score -531.08
# episode : 896 score -425.17 average_score -531.02
# episode : 897 score -525.02 average_score -530.34
# episode : 898 score -522.95 average_score -529.93
# episode : 899 score -578.13 average_score -530.32
# episode : 900 score -574.29 average_score -529.40
# episode : 901 score -462.69 average_score -529.83
# episode : 902 score -474.95 average_score -530.48
# episode : 903 score -384.57 average_score -529.48
# episode : 904 score -663.48 average_score -531.76
# episode : 905 score -611.04 average_score -531.93
# episode : 906 score -615.57 average_score -532.55
# ...
# episode : 1198 score -600.36 average_score -531.69
# episode : 1199 score -516.08 average_score -531.52
# episode : 1200 score -609.80 average_score -532.63
# episode : 1201 score -520.54 average_score -534.53
# episode : 1202 score -456.53 average_score -534.38
# episode : 1203 score -621.91 average_score -535.48
# episode : 1204 score -600.62 average_score -536.06
# episode : 1205 score -488.27 average_score -536.30
# episode : 1206 score -569.33 average_score -535.42
# episode : 1207 score -597.12 average_score -536.36
# episode : 1208 score -543.62 average_score -535.36
# episode : 1209 score -548.52 average_score -535.63
# episode : 1210 score -722.16 average_score -537.68
# episode : 1211 score -553.18 average_score -538.41
# episode : 1212 score -551.26 average_score -537.61
# episode : 1213 score -567.83 average_score -538.66
# episode : 1214 score -701.66 average_score -539.68
# episode : 1215 score -638.48 average_score -542.55
# episode : 1216 score -476.67 average_score -541.76
# episode : 1217 score -568.98 average_score -542.56
# episode : 1218 score -681.23 average_score -543.93
# episode : 1219 score -532.91 average_score -544.78
# episode : 1220 score -401.58 average_score -542.69
# episode : 1221 score -373.20 average_score -542.06
# episode : 1222 score -688.47 average_score -544.24
# episode : 1223 score -444.84 average_score -542.98
# episode : 1224 score -626.83 average_score -544.44
# episode : 1225 score -598.47 average_score -545.99
# episode : 1226 score -669.21 average_score -548.81
# episode : 1227 score -637.99 average_score -550.05
# episode : 1228 score -641.23 average_score -550.09
# episode : 1229 score -452.61 average_score -550.17
# episode : 1230 score -575.99 average_score -550.29
# episode : 1231 score -479.03 average_score -548.49
# episode : 1232 score -441.33 average_score -547.34
# episode : 1233 score -588.80 average_score -546.91
# episode : 1234 score -655.93 average_score -548.44
# episode : 1235 score -705.03 average_score -550.17
# episode : 1236 score -470.51 average_score -549.97
# episode : 1237 score -589.76 average_score -551.32
# episode : 1238 score -622.84 average_score -553.13
# episode : 1239 score -554.92 average_score -552.98
# episode : 1240 score -533.37 average_score -552.48
# episode : 1241 score -478.08 average_score -552.34
# episode : 1242 score -687.78 average_score -553.79
# episode : 1243 score -649.89 average_score -554.69
# episode : 1244 score -638.92 average_score -555.21
# episode : 1245 score -434.59 average_score -554.15
# episode : 1246 score -491.52 average_score -554.17
# episode : 1247 score -682.23 average_score -556.28
# episode : 1248 score -509.44 average_score -555.26
# episode : 1249 score -654.52 average_score -556.71
# episode : 1250 score -579.02 average_score -557.00
# episode : 1251 score -577.62 average_score -556.98
# episode : 1252 score -525.01 average_score -555.64
# episode : 1253 score -452.76 average_score -554.19
# episode : 1254 score -531.61 average_score -556.25
# episode : 1255 score -478.13 average_score -555.31
# episode : 1256 score -601.75 average_score -555.82
# episode : 1257 score -560.07 average_score -554.74
# episode : 1258 score -517.35 average_score -555.53
# episode : 1259 score -460.57 average_score -554.83
# episode : 1260 score -474.63 average_score -554.84
# episode : 1261 score -489.81 average_score -555.29
# episode : 1262 score -675.51 average_score -555.84
# episode : 1263 score -530.44 average_score -554.21
# episode : 1264 score -512.08 average_score -552.45
# episode : 1265 score -380.69 average_score -552.87
# episode : 1266 score -654.40 average_score -552.84
# episode : 1267 score -701.02 average_score -554.06
# episode : 1268 score -332.10 average_score -549.87
# episode : 1269 score -426.03 average_score -549.66
# episode : 1270 score -565.12 average_score -551.38
# episode : 1271 score -477.72 average_score -548.85
# episode : 1272 score -557.81 average_score -549.34
# episode : 1273 score -548.02 average_score -550.00
# episode : 1274 score -611.30 average_score -549.93
# episode : 1275 score -677.02 average_score -550.27
# episode : 1276 score -602.00 average_score -552.40
# episode : 1277 score -490.18 average_score -549.94
# episode : 1278 score -381.17 average_score -547.97
# episode : 1279 score -585.67 average_score -547.20
# episode : 1280 score -491.00 average_score -547.25
# episode : 1281 score -457.94 average_score -546.47
# episode : 1282 score -627.85 average_score -546.89
# episode : 1283 score -479.52 average_score -547.06
# episode : 1284 score -546.98 average_score -547.87
# episode : 1285 score -578.43 average_score -549.20
# episode : 1286 score -623.31 average_score -549.71
# episode : 1287 score -454.78 average_score -549.67
# episode : 1288 score -452.22 average_score -548.41
# episode : 1289 score -588.82 average_score -549.86
# episode : 1290 score -521.17 average_score -550.21
# episode : 1291 score -472.09 average_score -551.81
# episode : 1292 score -720.02 average_score -553.01
# episode : 1293 score -533.69 average_score -552.47
# episode : 1294 score -497.50 average_score -551.02
# episode : 1295 score -696.93 average_score -553.00
# episode : 1296 score -695.12 average_score -555.57
# episode : 1297 score -467.19 average_score -555.07
# episode : 1298 score -572.73 average_score -554.80
# episode : 1299 score -619.16 average_score -555.83
# episode : 1300 score -481.84 average_score -554.55
# episode : 1301 score -490.77 average_score -554.25
# episode : 1302 score -609.41 average_score -555.78
# episode : 1303 score -700.73 average_score -556.57
# episode : 1304 score -591.97 average_score -556.48
# episode : 1305 score -548.95 average_score -557.09
# episode : 1306 score -463.62 average_score -556.03
# episode : 1307 score -649.27 average_score -556.55
# episode : 1308 score -695.64 average_score -558.07
# episode : 1309 score -626.24 average_score -558.85
# episode : 1310 score -599.24 average_score -557.62
# episode : 1311 score -493.64 average_score -557.02
# episode : 1312 score -564.81 average_score -557.16
# episode : 1313 score -574.04 average_score -557.22
# episode : 1314 score -703.42 average_score -557.24
# episode : 1315 score -720.70 average_score -558.06
# episode : 1316 score -497.55 average_score -558.27
# episode : 1317 score -428.94 average_score -556.87
# episode : 1318 score -405.79 average_score -554.11
# episode : 1319 score -417.33 average_score -552.96
# episode : 1320 score -419.67 average_score -553.14
# episode : 1321 score -630.89 average_score -555.72
# episode : 1322 score -665.09 average_score -555.48
# episode : 1323 score -478.33 average_score -555.82
# episode : 1324 score -655.30 average_score -556.10
# episode : 1325 score -419.85 average_score -554.32
# episode : 1326 score -494.97 average_score -552.57
# episode : 1327 score -687.57 average_score -553.07
# episode : 1328 score -511.00 average_score -551.77
# episode : 1329 score -727.45 average_score -554.52
# episode : 1330 score -464.25 average_score -553.40
# episode : 1331 score -611.08 average_score -554.72
# episode : 1332 score -680.73 average_score -557.11
# episode : 1333 score -568.41 average_score -556.91
# episode : 1334 score -663.81 average_score -556.99
# episode : 1335 score -487.32 average_score -554.81
# episode : 1336 score -615.09 average_score -556.26
# episode : 1337 score -383.34 average_score -554.19
# episode : 1338 score -651.73 average_score -554.48
# episode : 1339 score -535.15 average_score -554.28
# episode : 1340 score -456.43 average_score -553.51
# episode : 1341 score -571.29 average_score -554.45
# episode : 1342 score -568.60 average_score -553.25
# episode : 1343 score -631.26 average_score -553.07
# episode : 1344 score -376.54 average_score -550.44
# episode : 1345 score -567.19 average_score -551.77
# episode : 1346 score -520.79 average_score -552.06
# episode : 1347 score -481.23 average_score -550.05
# episode : 1348 score -534.10 average_score -550.30
# episode : 1349 score -669.78 average_score -550.45
# episode : 1350 score -648.03 average_score -551.14
# episode : 1351 score -650.48 average_score -551.87
# episode : 1352 score -655.91 average_score -553.18
# episode : 1353 score -723.68 average_score -555.89
# episode : 1354 score -638.64 average_score -556.96
# episode : 1355 score -629.48 average_score -558.47
# episode : 1356 score -559.68 average_score -558.05
# episode : 1357 score -537.46 average_score -557.83
# episode : 1358 score -451.73 average_score -557.17
# episode : 1359 score -456.44 average_score -557.13
# episode : 1360 score -550.22 average_score -557.89
# episode : 1361 score -507.06 average_score -558.06
# episode : 1362 score -608.25 average_score -557.39
# episode : 1363 score -567.28 average_score -557.75
# episode : 1364 score -594.76 average_score -558.58
# episode : 1365 score -730.52 average_score -562.08
# episode : 1366 score -566.37 average_score -561.20
# episode : 1367 score -621.54 average_score -560.40
# episode : 1368 score -712.13 average_score -564.20
# episode : 1369 score -485.82 average_score -564.80
# episode : 1370 score -528.00 average_score -564.43
# episode : 1371 score -453.66 average_score -564.19
# episode : 1372 score -605.55 average_score -564.67
# episode : 1373 score -614.62 average_score -565.33
# episode : 1374 score -735.22 average_score -566.57
# episode : 1375 score -691.21 average_score -566.71
# episode : 1376 score -477.97 average_score -565.47
# episode : 1377 score -450.63 average_score -565.08
# episode : 1378 score -440.68 average_score -565.67
# episode : 1379 score -635.09 average_score -566.17
# episode : 1380 score -435.99 average_score -565.62
# episode : 1381 score -490.65 average_score -565.94
# episode : 1382 score -410.89 average_score -563.78
# episode : 1383 score -565.62 average_score -564.64
# episode : 1384 score -663.94 average_score -565.81
# episode : 1385 score -713.72 average_score -567.16
# episode : 1386 score -649.39 average_score -567.42
# episode : 1387 score -527.18 average_score -568.14
# episode : 1388 score -668.90 average_score -570.31
# episode : 1389 score -489.17 average_score -569.31
# episode : 1390 score -463.21 average_score -568.73
# episode : 1391 score -505.76 average_score -569.07
# episode : 1392 score -639.43 average_score -568.26
# episode : 1393 score -520.80 average_score -568.14
# episode : 1394 score -667.27 average_score -569.83
# episode : 1395 score -512.09 average_score -567.99
# episode : 1396 score -470.65 average_score -565.74
# episode : 1397 score -539.62 average_score -566.46
# episode : 1398 score -686.43 average_score -567.60
# episode : 1399 score -576.10 average_score -567.17
# episode : 1400 score -594.63 average_score -568.30
# episode : 1401 score -606.30 average_score -569.45
# episode : 1402 score -547.77 average_score -568.84
# episode : 1403 score -528.05 average_score -567.11
# episode : 1404 score -612.77 average_score -567.32
# episode : 1405 score -630.01 average_score -568.13
# episode : 1406 score -590.45 average_score -569.40
# episode : 1407 score -656.85 average_score -569.47
# episode : 1408 score -546.33 average_score -567.98
# episode : 1409 score -692.31 average_score -568.64
# episode : 1410 score -586.68 average_score -568.52
# episode : 1411 score -457.00 average_score -568.15
# episode : 1412 score -507.89 average_score -567.58
# episode : 1413 score -703.42 average_score -568.87
# episode : 1414 score -507.54 average_score -566.92
# episode : 1415 score -656.59 average_score -566.27
# episode : 1416 score -484.13 average_score -566.14
# episode : 1417 score -393.17 average_score -565.78
# episode : 1418 score -461.03 average_score -566.33
# episode : 1419 score -730.25 average_score -569.46
# episode : 1420 score -571.63 average_score -570.98
# episode : 1421 score -660.84 average_score -571.28
# episode : 1422 score -544.83 average_score -570.08
# episode : 1423 score -486.71 average_score -570.16
# episode : 1424 score -584.37 average_score -569.45
# episode : 1425 score -485.72 average_score -570.11
# episode : 1426 score -552.35 average_score -570.69
# episode : 1427 score -551.22 average_score -569.32
# episode : 1428 score -454.69 average_score -568.76
# episode : 1429 score -645.73 average_score -567.94
# episode : 1430 score -477.34 average_score -568.07
# episode : 1431 score -549.86 average_score -567.46
# episode : 1432 score -400.30 average_score -564.66
# episode : 1433 score -682.36 average_score -565.80
# episode : 1434 score -525.61 average_score -564.42
# episode : 1435 score -561.98 average_score -565.16
# episode : 1436 score -547.68 average_score -564.49
# episode : 1437 score -614.25 average_score -566.80
# episode : 1438 score -567.71 average_score -565.96
# episode : 1439 score -642.18 average_score -567.03
# episode : 1440 score -467.61 average_score -567.14
# episode : 1441 score -608.69 average_score -567.51
# episode : 1442 score -603.23 average_score -567.86
# episode : 1443 score -519.34 average_score -566.74
# episode : 1444 score -607.00 average_score -569.04
# episode : 1445 score -642.24 average_score -569.79
# episode : 1446 score -567.28 average_score -570.26
# episode : 1447 score -732.42 average_score -572.77
# episode : 1448 score -522.56 average_score -572.66
# episode : 1449 score -653.71 average_score -572.50
# episode : 1450 score -610.24 average_score -572.12
# episode : 1451 score -623.41 average_score -571.85
# episode : 1452 score -511.44 average_score -570.40
# episode : 1453 score -590.15 average_score -569.07
# episode : 1454 score -734.19 average_score -570.02
# episode : 1455 score -539.13 average_score -569.12
# episode : 1456 score -745.99 average_score -570.98
# episode : 1457 score -617.33 average_score -571.78
# episode : 1458 score -532.01 average_score -572.58
# episode : 1459 score -607.41 average_score -574.09
# episode : 1460 score -629.45 average_score -574.89
# episode : 1461 score -586.68 average_score -575.68
# episode : 1462 score -676.42 average_score -576.36
# episode : 1463 score -511.35 average_score -575.80
# episode : 1464 score -677.77 average_score -576.63
# episode : 1465 score -708.09 average_score -576.41
# episode : 1466 score -658.10 average_score -577.33
# episode : 1467 score -705.25 average_score -578.16
# episode : 1468 score -640.27 average_score -577.45
# episode : 1469 score -629.48 average_score -578.88
# episode : 1470 score -560.64 average_score -579.21
# episode : 1471 score -547.68 average_score -580.15
# episode : 1472 score -758.10 average_score -581.67
# episode : 1473 score -645.75 average_score -581.99
# episode : 1474 score -656.12 average_score -581.19
# episode : 1475 score -516.92 average_score -579.45
# episode : 1476 score -613.16 average_score -580.80
# episode : 1477 score -540.31 average_score -581.70
# episode : 1478 score -726.53 average_score -584.56
# episode : 1479 score -572.87 average_score -583.94
# episode : 1480 score -675.01 average_score -586.33
# episode : 1481 score -699.37 average_score -588.41
# episode : 1482 score -538.81 average_score -589.69
# episode : 1483 score -562.66 average_score -589.66
# episode : 1484 score -668.30 average_score -589.71
# episode : 1485 score -471.62 average_score -587.29
# episode : 1486 score -603.24 average_score -586.82
# episode : 1487 score -602.06 average_score -587.57
# episode : 1488 score -658.08 average_score -587.47
# episode : 1489 score -646.75 average_score -589.04
# episode : 1490 score -489.00 average_score -589.30
# episode : 1491 score -846.30 average_score -592.70
# episode : 1492 score -742.71 average_score -593.74
# episode : 1493 score -618.86 average_score -594.72
# episode : 1494 score -635.99 average_score -594.40
# episode : 1495 score -502.60 average_score -594.31
# episode : 1496 score -720.06 average_score -596.80
# episode : 1497 score -523.37 average_score -596.64
# episode : 1498 score -617.05 average_score -595.95
# episode : 1499 score -685.27 average_score -597.04

# %%
0.75**2+0.75**2
# Out:
# 1.125

# %%
# Out:
# {'env': <Monitor<Monitor<Monitor<Monitor<TimeLimit<LunarLanderContinuous<LunarLanderContinuous-v2>>>>>>>,
#  '_action_space': None,
#  '_observation_space': None,
#  '_reward_range': None,
#  '_metadata': None,
#  'videos': [],
#  'stats_recorder': <gym.wrappers.monitoring.stats_recorder.StatsRecorder at 0x7f06541ebf10>,
#  'video_recorder': None,
#  'enabled': True,
#  'episode_id': 0,
#  '_monitor_id': 5,
#  'env_semantics_autoreset': None,
#  'directory': '/home/delcey/Documents/Python/results',
#  'video_callable': <function gym.wrappers.monitor.capped_cubic_video_schedule(episode_id)>,
#  'file_prefix': 'openaigym',
#  'file_infix': '5.3792',
#  'write_upon_reset': False}

# %%
state = env.reset()
plt.imshow(env.render(mode='rgb_array'))
n = 200
score =0
done = False
while not done:
    action = agent.choose_action(state,epsilon = 0.0)
    state,reward,done,_ = env.step(action)
    
    score+=reward
    env.render('rgb_array')
print(score)
# Out:
# libGL error: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: iris
# libGL error: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: iris
# libGL error: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: swrast
# ---------------------------------------------------------------------------
# ContextException                          Traceback (most recent call last)
# /tmp/ipykernel_12634/934913299.py in <module>
#       1 state = env.reset()
# ----> 2 plt.imshow(env.render(mode='rgb_array'))
#       3 n = 200
#       4 score =0
#       5 done = False
#
# ~/anaconda3/envs/keras_gpu/lib/python3.9/site-packages/gym/core.py in render(self, mode, **kwargs)
#     293
#     294     def render(self, mode="human", **kwargs):
# --> 295         return self.env.render(mode, **kwargs)
#     296
#     297     def close(self):
#
# ~/anaconda3/envs/keras_gpu/lib/python3.9/site-packages/gym/envs/box2d/lunar_lander.py in render(self, mode)
#     386
#     387     def render(self, mode="human"):
# --> 388         from gym.envs.classic_control import rendering
#     389
#     390         if self.viewer is None:
#
# ~/anaconda3/envs/keras_gpu/lib/python3.9/site-packages/gym/envs/classic_control/rendering.py in <module>
#      25
#      26 try:
# ---> 27     from pyglet.gl import *
#      28 except ImportError as e:
#      29     raise ImportError(
#
# ~/anaconda3/envs/keras_gpu/lib/python3.9/site-packages/pyglet/gl/__init__.py in <module>
#     230     # trickery is for circular import
#     231     _pyglet.gl = _sys.modules[__name__]
# --> 232     import pyglet.window
#
# ~/anaconda3/envs/keras_gpu/lib/python3.9/site-packages/pyglet/window/__init__.py in <module>
#    1916 if not _is_pyglet_doc_run:
#    1917     pyglet.window = sys.modules[__name__]
# -> 1918     gl._create_shadow_window()
#
# ~/anaconda3/envs/keras_gpu/lib/python3.9/site-packages/pyglet/gl/__init__.py in _create_shadow_window()
#     204
#     205     from pyglet.window import Window
# --> 206     _shadow_window = Window(width=1, height=1, visible=False)
#     207     _shadow_window.switch_to()
#     208
#
# ~/anaconda3/envs/keras_gpu/lib/python3.9/site-packages/pyglet/window/xlib/__init__.py in __init__(self, *args, **kwargs)
#     169                     self._event_handlers[message] = func
#     170
# --> 171         super(XlibWindow, self).__init__(*args, **kwargs)
#     172
#     173         global _can_detect_autorepeat
#
# ~/anaconda3/envs/keras_gpu/lib/python3.9/site-packages/pyglet/window/__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, file_drops, display, screen, config, context, mode)
#     613
#     614         if not context:
# --> 615             context = config.create_context(gl.current_context)
#     616
#     617         # Set these in reverse order to above, to ensure we get user preference
#
# ~/anaconda3/envs/keras_gpu/lib/python3.9/site-packages/pyglet/gl/xlib.py in create_context(self, share)
#     202     def create_context(self, share):
#     203         if self.glx_info.have_extension('GLX_ARB_create_context'):
# --> 204             return XlibContextARB(self, share)
#     205         else:
#     206             return XlibContext13(self, share)
#
# ~/anaconda3/envs/keras_gpu/lib/python3.9/site-packages/pyglet/gl/xlib.py in __init__(self, config, share)
#     312 class XlibContext13(BaseXlibContext):
#     313     def __init__(self, config, share):
# --> 314         super(XlibContext13, self).__init__(config, share)
#     315         self.glx_window = None
#     316
#
# ~/anaconda3/envs/keras_gpu/lib/python3.9/site-packages/pyglet/gl/xlib.py in __init__(self, config, share)
#     216         if not self.glx_context:
#     217             # TODO: Check Xlib error generated
# --> 218             raise gl.ContextException('Could not create GL context')
#     219
#     220         self._have_SGI_video_sync = config.glx_info.have_extension('GLX_SGI_video_sync')
#
# ContextException: Could not create GL context

# %%
env.reset()
# Out:
# array([-0.00402613,  1.4208692 , -0.4078105 ,  0.44217455,  0.00467197,
#         0.09237514,  0.        ,  0.        ], dtype=float32)
